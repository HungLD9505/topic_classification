# %%
import json, random, torch
from bs4 import BeautifulSoup
import requests
from transformers import DistilBertForSequenceClassification, DistilBertTokenizerFast
from sklearn.metrics import accuracy_score, f1_score

# -------------------- Load model + tokenizer --------------------
model = DistilBertForSequenceClassification.from_pretrained("saved_model")
tokenizer = DistilBertTokenizerFast.from_pretrained("saved_model")
model.eval()
device = torch.device("cpu")
model.to(device)
# Out:
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): DistilBertSdpaAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=4, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
# -------------------- Load dataset URLs (chỉ để lấy URL ngẫu nhiên) --------------------
with open("dataset.json", "r", encoding="utf-8") as f:
    data = json.load(f)

sample_data = random.sample(data, min(100, len(data)))
urls = [item["url"] for item in sample_data]
true_labels = [item["label"] for item in sample_data]  # dùng để tính accuracy

# %%
# -------------------- Crawl plain text --------------------
def fetch_plain_text(url, max_len=5000):
    try:
        resp = requests.get(url, timeout=5, headers={"User-Agent":"Mozilla/5.0"})
        soup = BeautifulSoup(resp.content, "html.parser")
        for tag in soup(["script","style","footer","nav","iframe","form","button"]):
            tag.extract()
        text = " ".join(soup.get_text().split())
        return (url + " " + text)[:max_len]
    except:
        return url  # fallback nếu crawl lỗi

# -------------------- Prepare texts --------------------
texts = [fetch_plain_text(u) for u in urls]

# %%
# -------------------- Tokenize --------------------
encodings = tokenizer(texts, truncation=True, padding=True, max_length=512, return_tensors="pt")
input_ids = encodings["input_ids"].to(device)
attention_mask = encodings["attention_mask"].to(device)

# -------------------- Predict --------------------
with torch.no_grad():
    outputs = model(input_ids, attention_mask=attention_mask)
    preds_ids = torch.argmax(outputs.logits, dim=1).cpu().numpy()

# -------------------- Map labels --------------------
label2id = {"chính trị":0, "cờ bạc":1, "18+":2, "nội dung khác":3}
id2label = {v:k for k,v in label2id.items()}
pred_labels = [id2label[i] for i in preds_ids]

# -------------------- Accuracy & F1 --------------------
acc = accuracy_score(true_labels, pred_labels)
f1 = f1_score(true_labels, pred_labels, average="weighted")

print(f"Accuracy: {acc:.4f} | F1-score: {f1:.4f}\n")

# -------------------- Show predictions --------------------
for u, t, p in zip(urls, true_labels, pred_labels):
    print(f"URL: {u}\nTrue: {t} | Predicted: {p}\n")
# Out:
# Accuracy: 0.8900 | F1-score: 0.8946
#
# URL: https://vtv90.vip
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://fi88vn.store
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://chandungquyenluc.blogspot.se
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://hit20.club
# True: chính trị | Predicted: chính trị
#
# URL: https://link-vao-fun88.online
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://world-dive.com
# True: cờ bạc | Predicted: nội dung khác
#
# URL: https://789win-03.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://truyenff.net
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://qq88.cafe
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://bet88cc.xyz
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://phimmoichillv.net
# True: chính trị | Predicted: chính trị
#
# URL: https://8877999.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://b52club.wiki
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://98wincom.club
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://bolapquechoa.blogspot.ru
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://thanbai88.app
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://jbo837.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://j88.city
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://sa88081.com
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://sancathuycung.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://xocdiaonline.cloud
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://km88.moda
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://daga388.io
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://789winn.agency
# True: cờ bạc | Predicted: nội dung khác
#
# URL: https://jun88plus.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://gnbet.run
# True: cờ bạc | Predicted: nội dung khác
#
# URL: https://danluanvn.blogspot.in
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://qq88.tech
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://nhattruyennew.com
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://tq247.vip
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://chandungquyenluc8.blogspot.mx
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://bao-toquoc.blogspot.fr
# True: chính trị | Predicted: chính trị
#
# URL: https://www.icstudio.io
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://typhu88.com.co
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://live4.90phut12.live
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://fb88cafe.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://m88choingay.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://alo789.today
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://umicache.com
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://mb662.red
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://alo88.fun
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://magnoliasquarecentral.com
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://vuabet88.guru
# True: cờ bạc | Predicted: nội dung khác
#
# URL: https://vk1769.org
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://carrillo180.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://spankingslave.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://2qvnt03.com
# True: cờ bạc | Predicted: nội dung khác
#
# URL: https://vn.on8833.com
# True: cờ bạc | Predicted: nội dung khác
#
# URL: https://78bin.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://thangvietcongmu.blogspot.in
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://chandungquyenluc1.blogspot.co.uk
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://play-f88ld12.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://tahupedia.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://phim.xxxbuom.com
# True: 18+ | Predicted: 18+
#
# URL: https://ega59.net
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://ok9.mobi
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://fun88men.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://bj88la.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://xetaidaiviet.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://artkuwait.org
# True: chính trị | Predicted: chính trị
#
# URL: https://vvvwin208.com
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://tinxalo.blogspot.jp
# True: chính trị | Predicted: chính trị
#
# URL: https://vegasvuitet.com
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://fk88.win
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://onbet58.com
# True: cờ bạc | Predicted: nội dung khác
#
# URL: https://fb788.net
# True: cờ bạc | Predicted: nội dung khác
#
# URL: https://tuangeldelaguarda.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://vnbet88010.cc
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://wstar7777.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://w88vi8.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://daga8.so
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://vnonbet88.com
# True: cờ bạc | Predicted: nội dung khác
#
# URL: https://chungtoimuontudo2.wordpress.com
# True: chính trị | Predicted: chính trị
#
# URL: https://betwinner6.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://b45678.cc
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://5699301.top
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://kubett.solutions
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://bongvip58.online
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://amazingspacejourney.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://vlxx.porn
# True: 18+ | Predicted: 18+
#
# URL: https://sunwin.top
# True: 18+ | Predicted: cờ bạc
#
# URL: https://noichienperfect.site
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://w88u1.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://gemwin100.net
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://casino-vn.org
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://vswin8.net
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://tuoitre2015.blogspot.co.uk
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://sxkuangji.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://sv388vs.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://tuoitre2015.blogspot.de
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://totoslot138maxwin.icu
# True: cờ bạc | Predicted: nội dung khác
#
# URL: https://gamenohudoithuong.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://nhacaiuytinpro.xyz
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://good88vn.com.co
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://tk88.rocks
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://thanhnienconggiao.blogspot.ca
# True: nội dung khác | Predicted: nội dung khác
#
# URL: https://betofreeslot.com
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://kubet77.pro
# True: cờ bạc | Predicted: cờ bạc
#
# URL: https://sexxinh.com
# True: 18+ | Predicted: 18+
#
# URL: https://69vn5.org
# True: cờ bạc | Predicted: cờ bạc
